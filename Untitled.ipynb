# %%
env_content = """
DB_USER=postgres
DB_HOST=db.bcdnwqqntuqczwvdpdgq.supabase.co
DB_PORT=5432
DB_NAME=postgres
DB_PASSWORD=!m1d1000O252525
RESET_TABLES=true
"""

with open(".env", "w") as f:
    f.write(env_content.strip())

print("Successfully generated your .env file behind the scenes!")
# Out:
# Successfully generated your .env file behind the scenes!

# %%
import os
print(".env file exists:", os.path.exists(".env"))
# Out:
# .env file exists: True

# %%
gitignore_content = """
.env
.DS_Store
__pycache__/
*.ipynb_checkpoints/
"""

with open(".gitignore", "w") as f:
    f.write(gitignore_content.strip())

print("Successfully created .gitignore! Your password is now shielded from Git.")
# Out:
# Successfully created .gitignore! Your password is now shielded from Git.

# %%
example_content = """
DB_USER=your_postgres_username
DB_HOST=your_supabase_host_address
DB_PORT=5432
DB_NAME=postgres
DB_PASSWORD=your_secure_password_here
RESET_TABLES=true
"""

with open(".env.example", "w") as f:
    f.write(example_content.strip())

print("Successfully created .env.example template!")
# Out:
# Successfully created .env.example template!
